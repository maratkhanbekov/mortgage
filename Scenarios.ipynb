# %%
import imp
import tools
imp.reload(tools)
# Out:
# <module 'tools' from '/Users/marat/Documents/DS/git/tools.py'>

# %%
s = tools.investing_simulator(
        Scenario = 'Standard Mortgage',
        Income = 200000,
        IYearGrowth = 0,
        Expenses = 50000,
        EYearGrowth = 0,
        SavingsInitial = 0,
        PropertyPrice = 10000000,
        PPYearGrowth = 0,
        Years = 5,
        DepositRate = 0,
        Rent = 50000,
        RYearGrowth = 0,
        MortgageRate = 0.1,
        MortgageTermMonths = 120,
        isDetailed = True)
capital = s.execute()
# Out:
# Standard Mortgage 4.85M

# %%
s = tools.investing_simulator(
        Scenario = 'Early Repayment Mortgage',
        Income = 200000,
        IYearGrowth = 0,
        Expenses = 50000,
        EYearGrowth = 0,
        SavingsInitial = 0,
        PropertyPrice = 10000000,
        PPYearGrowth = 0,
        Years = 5,
        DepositRate = 0,
        Rent = 50000,
        RYearGrowth = 0,
        MortgageRate = 0.1,
        MortgageTermMonths = 120,
        isDetailed = True)
capital = s.execute()
# Out:
# Early Repayment Mortgage 5.38M

# %%
s = tools.investing_simulator(
        Scenario = 'Only Renting',
        Income = 200000,
        IYearGrowth = 0,
        Expenses = 50000,
        EYearGrowth = 0,
        SavingsInitial = 0,
        PropertyPrice = 10000000,
        PPYearGrowth = 0,
        Years = 5,
        DepositRate = 0,
        Rent = 50000,
        RYearGrowth = 0,
        MortgageRate = 0.1,
        MortgageTermMonths = 120,
        isDetailed = True)
capital = s.execute()
# Out:
# Only Renting 6.0M
